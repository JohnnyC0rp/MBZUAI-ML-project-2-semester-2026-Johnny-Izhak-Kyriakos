# %% [markdown]
# # Data Exploration And Figure Export
#
# This notebook regenerates the figures used in the paper and stores both **PNG** and **interactive HTML** outputs under `paper/figures/`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from creditsense_public.features import load_competition_data
from creditsense_public.reporting import build_report_figures

FIGURE_DIR = PROJECT_ROOT / "paper" / "figures"
data = load_competition_data()
train_df = data["train_df"]
train_df.head()
# Out:
#    Age  NumberOfDependents EducationLevel MaritalStatus HomeOwnership  \
# 0   39                   2         Master        Single          Rent
# 1   52                   1     No Diploma        Single          Rent
# 2   48                   0   Some College       Married          Rent
# 3   33                   1       Bachelor        Single          Rent
# 4   21                   0       Bachelor        Single          Rent
#
#    ResidencyYears          State  NumberOfDependentsUnder18 EmploymentStatus  \
# 0             5.4   Mid-Atlantic                          2        Full-Time
# 1            14.2      Northeast                          0          Retired
# 2             1.8  Pacific Coast                          0    Self-Employed
# 3             3.1   Great Plains                          1        Part-Time
# 4             0.1      Northwest                          0        Full-Time
#
#    EmploymentLengthYears  ... RequestedTermMonths HasCoApplicant  \
# ...

# %%
train_df[["RiskTier", "InterestRate"]].describe(include="all")
# Out:
#            RiskTier  InterestRate
# count  35000.000000  35000.000000
# mean       2.012771      7.313440
# std        1.411375      4.193545
# min        0.000000      4.990000
# 25%        1.000000      4.990000
# 50%        2.000000      6.080000
# 75%        3.000000      7.940000
# max        4.000000     35.990000

# %%
figure_paths = build_report_figures(FIGURE_DIR)
figure_paths
# Out:
# {'class_distribution': {'png': PosixPath('/Users/rotte.sergeevich/Documents/Programming/ml proj banks clients/github_public_version/paper/figures/class_distribution.png'),
#   'html': PosixPath('/Users/rotte.sergeevich/Documents/Programming/ml proj banks clients/github_public_version/paper/figures/interactive/class_distribution.html')},
#  'missingness': {'png': PosixPath('/Users/rotte.sergeevich/Documents/Programming/ml proj banks clients/github_public_version/paper/figures/missingness_overview.png'),
#   'html': PosixPath('/Users/rotte.sergeevich/Documents/Programming/ml proj banks clients/github_public_version/paper/figures/interactive/missingness_overview.html')},
#  'stage_progress': {'png': PosixPath('/Users/rotte.sergeevich/Documents/Programming/ml proj banks clients/github_public_version/paper/figures/stage_progress.png'),
# ...

# %% [markdown]
# ## Quick observations
#
# - Missingness is structured rather than random, especially for asset and collateral fields.
# - The classes are reasonably balanced, which makes accuracy a fair summary metric.
# - Interest rate climbs cleanly with risk tier, so the two tasks are related but not identical.
